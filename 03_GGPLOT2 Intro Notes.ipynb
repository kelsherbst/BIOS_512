# %%
library('palmerpenguins')
library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
penguins |> head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
# What are the endodings?

options(repr.plot.res = 250, repr.plot.height = 3, repr.plot.width = 5) 

p = ggplot(penguins, aes(x = bill_length_mm, y = flipper_length_mm, color = species)) + 
    geom_point(na.rm = T) +
    scale_color_brewer(palette = 'Set2') +
    labs(x = 'Bill length, mm', y = 'Flipper length, mm', color = 'Species')

p
# Out:
# plot without title

# %% [markdown]
# #GGPLOT2 Intro
# Start with your data

# %%
mpg |> head()
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
# ?mpg

# %% [markdown]
# What kind of chart are you trying to make?
#
# What is on the axes?
# What kind of shapes represent the data?
# E.g. bars, points?
# Do you have a column in your data that represents each chart property?
# What are the encodings?

# %%
# Trick to set chart output size in Jupyter
options(repr.plot.width = 5, repr.plot.height = 3)

# %% [markdown]
# 1. start with `ggplot` function
# 2. encodings are defined with the `aes` function
# 3. we pass in the data as the first "argument"
# 4. we pass sncodings to `ggplot` in the second argument
# 5. capture the output

# %%
encodings = aes(x = displ, y = hwy)
p = ggplot(mpg, encodings) #mpg is data, whree do "hwy
#and displ come from
p
# Out:
# plot without title

# %% [markdown]
# add the `geom` you want to represent the data

# %%
p = p + geom_point(size=2)

p
# Out:
# plot without title

# %% [markdown]
# # Color the data points by `class`

# %%
encodings = aes(x = displ, y = hwy, color = class)

p = ggplot(mpg, encodings)

p = p + geom_point(size = 2)

p
# Out:
# plot without title
